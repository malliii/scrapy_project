# %%
import pandas as pd

# %%
c1 = pd.read_csv("metacritic_xbox1.csv")
c2 = pd.read_csv("metacriticPc.csv")
c3 = pd.read_csv("metacriticPs4.csv")
c4 = pd.read_csv("metacriticPs5.csv")
c5 = pd.read_csv("metacriticSwitch.csv")
c6 = pd.read_csv("metacriticXboxSX.csv")

# %%
c1.head()
# Out:
#    meta_score  page platform  \
# 0         NaN     1  XboxOne
# 1         NaN     1  XboxOne
# 2         NaN     1  XboxOne
# 3         NaN     1  XboxOne
# 4         NaN     1  XboxOne
#
#                                        product_genre   release_date  \
# 0  Action,Action Adventure,Platformer,Open-World,...  April 6, 2023
# 1          Action,Strategy,Real-Time,General,Defense  April 6, 2023
# 2                               Action,Platformer,2D  April 7, 2023
# 3                          Action Adventure,Survival  April 7, 2023
# 4                               Action,Platformer,3D  April 7, 2023
#
#                                              summary  \
# 0  Curse of the Sea Rats is a 'ratoidvania' platf...
# 1  A high-tempo shooting game with simple control...
# 2  Join the cute Bumballon on this frantic advent...
# 3  In this horror game, you'll have to immerse yo...
# 4  Start the best Enigmatic Adventure of your lif...
#
# ...

# %%
c2.head()
# Out:
#    meta_score  page platform                          product_genre  \
# 0         NaN     1       PC                    Racing,Arcade,Other
# 1        84.0     1       PC     Action Adventure,Adventure,General
# 2         NaN     1       PC  Action,Adventure,General,Shooter,Rail
# 3         NaN     2       PC               Adventure,Puzzle,General
# 4         NaN     2       PC  Action,Adventure,General,Visual Novel
#
#      release_date                                            summary  \
# 0  April 13, 2023  From the creators of PHOGS!, Tray Racers! is a...
# 1  April 13, 2023  Hunt the Night is a retro-style action-adventu...
# 2  April 11, 2023  After drinking a lot with your friends at the ...
# 3   April 7, 2023  STRIPPERS - is the simplest 2D puzzle the fina...
# 4   April 7, 2023  You're a graduating university student but sti...
#
#              title  user_score
# 0     Tray Racers!         NaN
# 1   Hunt the Night         NaN
# 2    Crystal Blast         NaN
# ...

# %%
c3.head()
# Out:
#    meta_score  page      platform  \
# 0         NaN     1  PlayStation4
# 1         NaN     1  PlayStation4
# 2         NaN     1  PlayStation4
# 3         NaN     1  PlayStation4
# 4         NaN     1  PlayStation4
#
#                                        product_genre   release_date  \
# 0                               Action,Platformer,2D  April 9, 2023
# 1          Action,Strategy,Real-Time,General,Defense  April 6, 2023
# 2                               Action,Platformer,2D  April 7, 2023
# 3                          Action Adventure,Survival  April 7, 2023
# 4  Action,Action Adventure,Platformer,Open-World,...  April 6, 2023
#
#                                              summary  \
# 0  Far into the future after technology has devel...
# 1  A high-tempo shooting game with simple control...
# 2  Inspired by Jorge Luis Borges' short story of ...
# 3  In this mode, the player selects a Resi 4 char...
# 4  Curse of the Sea Rats is a 'ratoidvania' platf...
#
# ...

# %%
c4.head()
# Out:
#    meta_score  page      platform                              product_genre  \
# 0        76.0     1  PlayStation5          General,Adventure,3D,Third-Person
# 1         NaN     1  PlayStation5  Action,Strategy,Real-Time,General,Defense
# 2         NaN     1  PlayStation5                       Action,Platformer,2D
# 3         NaN     1  PlayStation5       Action,Shooter,Shoot-'Em-Up,Top-Down
# 4         NaN     1  PlayStation5                  Action Adventure,Survival
#
#      release_date                                            summary  \
# 0  April 11, 2023  Sherlock Holmes: The Awakened remake sees a yo...
# 1   April 6, 2023  A high-tempo shooting game with simple control...
# 2   April 9, 2023  Far into the future after technology has devel...
# 3  April 11, 2023  The Future… Earth is attacked by rebels from V...
# 4   April 7, 2023  In this mode, the player selects a Resi 4 char...
#
#                               title  user_score
# ...

# %%
c5.head()
# Out:
#    meta_score  page platform                         product_genre  \
# 0         NaN     1   Switch       Strategy,Turn-Based,Card Battle
# 1         NaN     1   Switch                         Puzzle,Action
# 2         NaN     1   Switch                Adventure,Visual Novel
# 3         NaN     1   Switch  Action,Shooter,Shoot-'Em-Up,Top-Down
# 4         NaN     1   Switch                  Role-Playing,General
#
#      release_date                                            summary  \
# 0  April 13, 2023  10 new cards appear in LogiKing LEVEL2 !!\rKee...
# 1  April 13, 2023  Paint yourself to solve the puzzles!\r\rSokolo...
# 2  April 13, 2023  With Sable's first year at Amadronia coming to...
# 3  April 13, 2023  A new game about tanks with dynamic battles.Ma...
# 4  April 13, 2023  Defeat the demon king with a monster girl as a...
#
#                                    title  user_score
# 0                        LogiKing LEVEL2         NaN
# ...

# %%
c6.head()
# Out:
#    meta_score  page platform                      product_genre  \
# 0         NaN     1   XboxSX          Action Adventure,Survival
# 1        84.0     1   XboxSX           Action Adventure,General
# 2         NaN     1   XboxSX    Strategy,Turn-Based,Card Battle
# 3        76.0     1   XboxSX  Adventure,General,3D,Third-Person
# 4         NaN     1   XboxSX               Action,Platformer,2D
#
#      release_date                                            summary  \
# 0   April 7, 2023  In this mode, the player selects a Resi 4 char...
# 1  April 12, 2023  Save a Tokyo under siege by spirits in a new a...
# 2  April 10, 2023  From the creator of Pony Island and The Hex co...
# 3  April 11, 2023  Sherlock Holmes: The Awakened remake sees a yo...
# 4   April 7, 2023  Inspired by Jorge Luis Borges' short story of ...
#
#                               title  user_score
# 0  Resident Evil 4: The Mercenaries         NaN
# 1                  GhostWire: Tokyo         NaN
# ...

# %%
combined = pd.concat([c1, c2, c3, c4, c5, c6], ignore_index=True)

# %%
cols = ['title', 'platform', 'product_genre', 'release_date', 'meta_score', 'user_score','summary']

# %%
combined = combined[cols]

# %%
combined.head()
# Out:
#                                      title platform  \
# 0                    Curse of the Sea Rats  XboxOne
# 1                                 Marfusha  XboxOne
# 2                                Bumballon  XboxOne
# 3                 Horror Tale 1: Kidnapper  XboxOne
# 4  Joe Wander and the Enigmatic adventures  XboxOne
#
#                                        product_genre   release_date  \
# 0  Action,Action Adventure,Platformer,Open-World,...  April 6, 2023
# 1          Action,Strategy,Real-Time,General,Defense  April 6, 2023
# 2                               Action,Platformer,2D  April 7, 2023
# 3                          Action Adventure,Survival  April 7, 2023
# 4                               Action,Platformer,3D  April 7, 2023
#
#    meta_score  user_score                                            summary
# 0         NaN         0.0  Curse of the Sea Rats is a 'ratoidvania' platf...
# 1         NaN         NaN  A high-tempo shooting game with simple control...
# ...

# %%
combined.to_csv("metacritic.csv")
